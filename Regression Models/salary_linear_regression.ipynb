# %% [markdown]
# <a href="https://colab.research.google.com/github/shirish-baral/machine-learning-with-python-coursera/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Salary.csv'
df = pd.read_csv(file_path)
print("Sample Dataset")
print(df.head())

# Prepare the data
X = df['YearsExperience'].values.reshape(-1, 1)
y = df['Salary'].values

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Print the model coefficients
print("\nModel Coefficients:")
intercept = model.intercept_
slope = model.coef_[0]
print(f"Intercept: {intercept:.2f}")
print(f"Slope: {slope:.2f}")

# Plot the results
print("\nPlotting Results:")
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Regression line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression: Salary vs Years of Experience')
plt.legend()
plt.show()
# Out:
# Sample Dataset
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
#
# Model Coefficients:
# Intercept: 28859.53
# Slope: 8731.94
#
# Plotting Results:

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Calculate R-squared
r_squared = r2_score(y, y_pred)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))

# Print the results
print(f"R-squared: {r_squared:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# R-squared: 0.97
# RMSE: 5916.65
